# %% [markdown]
# # คำนวณ MFB และสถิติอื่น ๆ ของทุกเรดาร์ ด้วยการเทียบกับฝนสถานี เพื่อนำไปปรับแก้ bias แต่ละสถานีก่อนไปโมเสค
# * จะได้ผลลัพธ์ค่า MFB แต่ละสถานีเรดาร์ ที่คำนวณโดยใช้ฝนสถานี สามารถนำเอา MFB ไปใช้ปรับแก้เพื่อลดค่าเอนเอียงได้

# %%
'''
2024.09.22
โค้ดนี้พัฒนาโดย รองศาสตราจารย์ ดร. นัฐพล มหาวิค ภาควิชาทรัพยากรธรรมชาติและสิ่งแวดล้อม คณะเกษตรศาสตร์ฯ มหาวิทยาลัยนเรศวร 
ในงานวิจัย เรื่อง "การวิจัยและพัฒนาผลิตภัณฑ์โมเสคฝนประมาณค่าจากเรดาร์ตรวจอากาศในพื้นที่ระดับลุ่มน้ำของประเทศไทยด้วยเทคโนโลยีภูมิสารสนเทศรหัสเปิด"
สนับสนุนทุนวิจัยโดยสํานักงานการวิจัยแห่งชาติ (วช.)  แผนงานการวิจัยและนวัตกรรมแผนงานด้านการบริหารจัดการภัยพิบัติทางธรรมชาติ 
ประจำปีงบประมาณ 2566  ตามสัญญา เลขที่ N25A660467 ผู้นำโค้ดนี้ไปใช้หรือดัดแปลงควรอ้างอิงงานวิจัยชิ้นนี้ตามหลักเกณฑ์การอ้างอิงสากล
เรียนหลักการเรดาร์และภูมิสารสนเทศ ที่ https://www.youtube.com/@Nattapon_Mahavik/playlists
หนังสือเรดาร์ตรวจอากาศทางอุตุนิยมวิทยา สำนักพิมพ์จุฬาฯ : https://www.chulabook.com/education/144567
หนังสือออนไลน์เรดาร์ตรวจอากาศทางอุตุนิยมวิทยา สำนักพิมพ์จุฬาฯ : https://www.chulabook.com/education/205129
ติดต่อ nattaponm@nu.ac.th
'''

# perfect codes
import os
import numpy as np
import pandas as pd
import rasterio
from tqdm import tqdm
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from collections import defaultdict
import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning)

def ensure_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def read_radar_data(file_path):
    with rasterio.open(file_path) as src:
        return src.read(1), src.transform

def extract_radar_rainfall(lon, lat, radar_data, transform):
    row, col = rasterio.transform.rowcol(transform, lon, lat)
    return radar_data[row, col]

def dbz_to_rainfall(dbz, zr_relation):
    Z = 10 ** (dbz / 10)  # Convert dBZ to Z
    
    zr_relations = {
        'marshall-palmer': (200, 1.6),
        'rosenfeld-tropical': (250, 1.2),
        'summer-deep-convective': (300, 1.4)
    }
    
    a, b = zr_relations[zr_relation]
    R = (Z / a) ** (1 / b)
    return R

def calculate_metrics(observed, predicted):
    if len(observed) < 2:
        return {metric: np.nan for metric in ['MSE', 'RMSE', 'R-squared', 'MAE', 'NSE', 'PBIAS', 'Correlation', 'MFB', 'Data_Count']}
    
    mse = mean_squared_error(observed, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(observed, predicted)
    mae = mean_absolute_error(observed, predicted)
    
    try:
        nse = 1 - (np.sum((observed - predicted)**2) / np.sum((observed - np.mean(observed))**2))
    except ZeroDivisionError:
        nse = np.nan
    
    try:
        pbias = np.sum(predicted - observed) / np.sum(observed) * 100
    except ZeroDivisionError:
        pbias = np.nan
    
    correlation = np.corrcoef(observed, predicted)[0, 1]
    
    try:
        mfb = np.mean(observed) / np.mean(predicted) # ถ้าค่า mfb > 1 ฝนเรดาร์ประมาณค่าได้น้อยกว่าฝนภาคพื้นดิน
               
    except ZeroDivisionError:
        mfb = np.nan
    
    return {
        'MSE': mse,
        'RMSE': rmse,
        'R-squared': r2,
        'MAE': mae,
        'NSE': nse,
        'PBIAS': pbias,
        'Correlation': correlation,
        'MFB': mfb,
        'Data_Count': len(observed)
    }

def process_data(radar_dir, gauge_dir, match_files_dir, radar_names, thresholds):
    zr_relations = ['marshall-palmer', 'rosenfeld-tropical', 'summer-deep-convective']
    all_results = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))

    for radar in tqdm(radar_names, desc="Processing radars"):
        radar_specific_dir = os.path.join(radar_dir, f'00outp_cappi_2km_{radar}')
        gauge_specific_dir = os.path.join(gauge_dir, radar, 'hourly')
        match_file_path = os.path.join(match_files_dir, f'matched_files_{radar}.csv')
        
        if not os.path.exists(radar_specific_dir) or not os.path.exists(gauge_specific_dir) or not os.path.exists(match_file_path):
            print(f"Warning: Required directories or match file not found for {radar}")
            continue
        
        match_data = pd.read_csv(match_file_path)
        
        for zr in zr_relations:
            filtered_data_by_threshold = {threshold: [] for threshold in thresholds}
            
            for _, row in tqdm(match_data.iterrows(), desc=f"Processing {radar} files for {zr}", total=len(match_data)):
                radar_file_path = os.path.join(radar_specific_dir, row['Radar_File'])
                gauge_file_path = os.path.join(gauge_specific_dir, row['Gauge_File'])
                
                if not os.path.exists(radar_file_path) or not os.path.exists(gauge_file_path):
                    print(f"Warning: File not found: {row['Radar_File']} or {row['Gauge_File']}")
                    continue
                
                try:
                    radar_data, transform = read_radar_data(radar_file_path)
                    gauge_data = pd.read_csv(gauge_file_path)
                    
                    radar_rainfall = dbz_to_rainfall(radar_data, zr)
                    gauge_data['radar_rainfall'] = gauge_data.apply(
                        lambda x: extract_radar_rainfall(x['longitude'], x['latitude'], radar_rainfall, transform),
                        axis=1
                    )
                    
                    for threshold in thresholds:
                        hourly_filtered = gauge_data[
                            (gauge_data['rain'] > threshold) & 
                            (gauge_data['radar_rainfall'] > threshold)
                        ]
                        if not hourly_filtered.empty:
                            filtered_data_by_threshold[threshold].append(hourly_filtered)
                
                except Exception as e:
                    print(f"Error processing data for {row['Radar_File']}: {str(e)}")
                    continue
            
            for threshold in thresholds:
                if filtered_data_by_threshold[threshold]:
                    aggregated_data = pd.concat(filtered_data_by_threshold[threshold])
                    
                    # Explicitly specify which columns to sum
                    columns_to_sum = ['rain', 'radar_rainfall']
                    
                    event_data = aggregated_data.groupby(['station_code', 'longitude', 'latitude'])[columns_to_sum].sum().reset_index()
                    
                    if len(event_data) > 0:
                        metrics = calculate_metrics(event_data['rain'], event_data['radar_rainfall'])
                    else:
                        metrics = {'Data_Count': 0}
                    
                    all_results[radar][zr][threshold]['full_event'] = metrics
                else:
                    all_results[radar][zr][threshold]['full_event'] = {'Data_Count': 0}

    return all_results

def save_detailed_results(results, output_dir):
    ensure_dir(output_dir)
    
    all_data = []
    for radar in results:
        for zr in results[radar]:
            for threshold in results[radar][zr]:
                metrics = results[radar][zr][threshold]['full_event']
                row = {
                    'Radar': radar,
                    'ZR_Relation': zr,
                    'Threshold': threshold,
                    'Event': 'full_event'
                }
                row.update(metrics)
                all_data.append(row)
    
    df = pd.DataFrame(all_data)
    df.to_csv(os.path.join(output_dir, 'detailed_results.csv'), index=False)

def create_summary(results):
    summary = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))
    
    for radar in results:
        for zr in results[radar]:
            for threshold in results[radar][zr]:
                summary[radar][zr][threshold] = results[radar][zr][threshold]['full_event']
    
    return summary

def save_summary(summary, output_dir):
    ensure_dir(output_dir)
    
    all_data = []
    for radar in summary:
        for zr in summary[radar]:
            for threshold in summary[radar][zr]:
                row = {
                    'Radar': radar,
                    'ZR_Relation': zr,
                    'Threshold': threshold
                }
                row.update(summary[radar][zr][threshold])
                all_data.append(row)
    
    df = pd.DataFrame(all_data)
    df.to_csv(os.path.join(output_dir, 'summary_results.csv'), index=False)
    
    print("Summary of Results:")
    print(df.to_string())

def main():
    radar_dir = '../00run_batch_acchr_codes/2output/0Hourly/0Sontihn_dbz_single/0processing_single_cappi/'
    gauge_dir = './0Zprocessing_data/0hourly_rain_each_radar/'
    match_files_dir = './0Zprocessing_data/0match_files/'
    output_dir = './0Zprocessing_data/0analysis_results/'
    
    thresholds = [0, 0.1, 0.5, 1, 2, 5, 10]
    radar_names = ['CHN', 'CMP', 'CRI', 'KKN', 'KRB', 'LMP', 'NRT', 'PHS', 'PKT', 'SNK', 'STP', 'SVP']
    #radar_names = ['CHN']

    results = process_data(radar_dir, gauge_dir, match_files_dir, radar_names, thresholds)
    save_detailed_results(results, output_dir)

    summary = create_summary(results)
    save_summary(summary, output_dir)

    print(f"\nDetailed results and summary saved in {output_dir}")

if __name__ == "__main__":
    main()
# Out:
# Processing radars:   0%|                                                                        | 0/12 [00:00<?, ?it/s]
# Processing CHN files for marshall-palmer:   0%|                                                | 0/240 [00:00<?, ?it/s]
# Processing CHN files for marshall-palmer:   0%|▏                                       | 1/240 [00:00<00:29,  8.19it/s]
# Processing CHN files for marshall-palmer:   1%|▎                                       | 2/240 [00:00<00:25,  9.16it/s]
# Processing CHN files for marshall-palmer:   1%|▌                                       | 3/240 [00:00<00:25,  9.47it/s]
# Processing CHN files for marshall-palmer:   2%|▋                                       | 4/240 [00:00<00:24,  9.65it/s]
# Processing CHN files for marshall-palmer:   2%|█                                       | 6/240 [00:00<00:23,  9.94it/s]
# Processing CHN files for marshall-palmer:   3%|█▎                                      | 8/240 [00:00<00:23, 10.08it/s]
# Processing CHN files for marshall-palmer:  98%|█████████████████████████████████████▏| 235/240 [00:22<00:00, 10.21it/s]
# Processing CHN files for marshall-palmer:  99%|█████████████████████████████████████▌| 237/240 [00:22<00:00, 10.12it/s]
# Processing CHN files for marshall-palmer: 100%|██████████████████████████████████████| 240/240 [00:23<00:00, 10.31it/s]
#
# Processing CHN files for rosenfeld-tropical:   0%|                                             | 0/240 [00:00<?, ?it/s]
# Processing CHN files for rosenfeld-tropical:   1%|▎                                    | 2/240 [00:00<00:19, 12.38it/s]
# Processing CHN files for rosenfeld-tropical:   2%|▌                                    | 4/240 [00:00<00:19, 12.18it/s]
# Processing CHN files for rosenfeld-tropical:   2%|▉                                    | 6/240 [00:00<00:19, 12.23it/s]
# Processing CHN files for rosenfeld-tropical:   3%|█▏                                   | 8/240 [00:00<00:18, 12.26it/s]
# Processing CHN files for rosenfeld-tropical:   4%|█▌                                  | 10/240 [00:00<00:18, 12.28it/s]
# Processing CHN files for rosenfeld-tropical:   5%|█▊                                  | 12/240 [00:00<00:18, 12.45it/s]
# Processing CHN files for rosenfeld-tropical:   6%|██                                  | 14/240 [00:01<00:18, 12.35it/s]
# Processing CHN files for rosenfeld-tropical:   7%|██▍                                 | 16/240 [00:01<00:18, 12.29it/s]
# Processing CHN files for rosenfeld-tropical:   8%|██▋                                 | 18/240 [00:01<00:18, 12.31it/s]
# Processing CHN files for rosenfeld-tropical:   8%|███                                 | 20/240 [00:01<00:17, 12.33it/s]
# Processing CHN files for rosenfeld-tropical:   9%|███▎                                | 22/240 [00:01<00:17, 12.41it/s]
# Processing CHN files for rosenfeld-tropical:  10%|███▌                                | 24/240 [00:01<00:17, 12.50it/s]
# Processing CHN files for rosenfeld-tropical:  11%|███▉                                | 26/240 [00:02<00:18, 11.89it/s]
# Processing CHN files for rosenfeld-tropical:  12%|████▏                               | 28/240 [00:02<00:17, 12.20it/s]
# Processing CHN files for rosenfeld-tropical:  12%|████▌                               | 30/240 [00:02<00:17, 12.20it/s]
# Processing CHN files for rosenfeld-tropical:  13%|████▊                               | 32/240 [00:02<00:17, 12.17it/s]
# Processing CHN files for rosenfeld-tropical:  14%|█████                               | 34/240 [00:02<00:16, 12.33it/s]
# Processing CHN files for rosenfeld-tropical:  15%|█████▍                              | 36/240 [00:02<00:16, 12.50it/s]
# Processing CHN files for rosenfeld-tropical:  16%|█████▋                              | 38/240 [00:03<00:16, 12.58it/s]
# Processing CHN files for rosenfeld-tropical:  17%|██████                              | 40/240 [00:03<00:15, 12.53it/s]
# Processing CHN files for rosenfeld-tropical:  18%|██████▎                             | 42/240 [00:03<00:15, 12.68it/s]
# Processing CHN files for rosenfeld-tropical:  18%|██████▌                             | 44/240 [00:03<00:15, 12.71it/s]
# Processing CHN files for rosenfeld-tropical:  19%|██████▉                             | 46/240 [00:03<00:15, 12.61it/s]
# Processing CHN files for rosenfeld-tropical:  20%|███████▏                            | 48/240 [00:03<00:15, 12.51it/s]
# Processing CHN files for rosenfeld-tropical:  21%|███████▌                            | 50/240 [00:04<00:15, 12.40it/s]
# Processing CHN files for rosenfeld-tropical:  22%|███████▊                            | 52/240 [00:04<00:15, 12.25it/s]
# Processing CHN files for rosenfeld-tropical:  22%|████████                            | 54/240 [00:04<00:15, 12.24it/s]
# Processing CHN files for rosenfeld-tropical:  23%|████████▍                           | 56/240 [00:04<00:15, 12.24it/s]
# Processing CHN files for rosenfeld-tropical:  24%|████████▋                           | 58/240 [00:04<00:14, 12.19it/s]
# Processing CHN files for rosenfeld-tropical:  25%|█████████                           | 60/240 [00:04<00:14, 12.36it/s]
# Processing CHN files for rosenfeld-tropical:  26%|█████████▎                          | 62/240 [00:05<00:14, 12.51it/s]
# Processing CHN files for rosenfeld-tropical:  27%|█████████▌                          | 64/240 [00:05<00:14, 12.56it/s]
# Processing CHN files for rosenfeld-tropical:  28%|█████████▉                          | 66/240 [00:05<00:13, 12.77it/s]
# Processing CHN files for rosenfeld-tropical:  28%|██████████▏                         | 68/240 [00:05<00:13, 12.77it/s]
# Processing CHN files for rosenfeld-tropical:  29%|██████████▌                         | 70/240 [00:05<00:13, 12.77it/s]
# Processing CHN files for rosenfeld-tropical:  30%|██████████▊                         | 72/240 [00:05<00:13, 12.82it/s]
# Processing CHN files for rosenfeld-tropical:  31%|███████████                         | 74/240 [00:05<00:12, 12.82it/s]
# Processing CHN files for rosenfeld-tropical:  32%|███████████▍                        | 76/240 [00:06<00:12, 12.86it/s]
# Processing CHN files for rosenfeld-tropical:  32%|███████████▋                        | 78/240 [00:06<00:12, 12.81it/s]
# Processing CHN files for rosenfeld-tropical:  33%|████████████                        | 80/240 [00:06<00:12, 12.84it/s]
# Processing CHN files for rosenfeld-tropical:  34%|████████████▎                       | 82/240 [00:06<00:11, 13.33it/s]
# Processing CHN files for rosenfeld-tropical:  35%|████████████▌                       | 84/240 [00:06<00:11, 13.21it/s]
# Processing CHN files for rosenfeld-tropical:  36%|████████████▉                       | 86/240 [00:06<00:11, 13.10it/s]
# Processing CHN files for rosenfeld-tropical:  37%|█████████████▏                      | 88/240 [00:07<00:11, 13.04it/s]
# Processing CHN files for rosenfeld-tropical:  38%|█████████████▌                      | 90/240 [00:07<00:11, 13.02it/s]
# Processing CHN files for rosenfeld-tropical:  38%|█████████████▊                      | 92/240 [00:07<00:11, 12.90it/s]
# Processing CHN files for rosenfeld-tropical:  39%|██████████████                      | 94/240 [00:07<00:11, 12.81it/s]
# Processing CHN files for rosenfeld-tropical:  40%|██████████████▍                     | 96/240 [00:07<00:11, 12.73it/s]
# Processing CHN files for rosenfeld-tropical:  41%|██████████████▋                     | 98/240 [00:07<00:11, 12.71it/s]
# Processing CHN files for rosenfeld-tropical:  42%|██████████████▌                    | 100/240 [00:07<00:11, 12.65it/s]
# Processing CHN files for rosenfeld-tropical:  42%|██████████████▉                    | 102/240 [00:08<00:10, 12.57it/s]
# Processing CHN files for rosenfeld-tropical:  43%|███████████████▏                   | 104/240 [00:08<00:10, 12.58it/s]
# Processing CHN files for rosenfeld-tropical:  88%|██████████████████████████████▉    | 212/240 [00:16<00:02, 12.52it/s]
# Processing CHN files for rosenfeld-tropical:  89%|███████████████████████████████▏   | 214/240 [00:16<00:02, 12.46it/s]
# Processing CHN files for rosenfeld-tropical:  90%|███████████████████████████████▌   | 216/240 [00:17<00:01, 12.53it/s]
# Processing CHN files for rosenfeld-tropical:  91%|███████████████████████████████▊   | 218/240 [00:17<00:01, 12.41it/s]
# Processing CHN files for rosenfeld-tropical:  92%|████████████████████████████████   | 220/240 [00:17<00:01, 12.44it/s]
# Processing CHN files for rosenfeld-tropical:  92%|████████████████████████████████▍  | 222/240 [00:17<00:01, 12.42it/s]
# Processing CHN files for rosenfeld-tropical:  93%|████████████████████████████████▋  | 224/240 [00:17<00:01, 12.54it/s]
# Processing CHN files for rosenfeld-tropical:  94%|████████████████████████████████▉  | 226/240 [00:17<00:01, 12.59it/s]
# Processing CHN files for rosenfeld-tropical:  95%|█████████████████████████████████▎ | 228/240 [00:18<00:00, 12.61it/s]
# Processing CHN files for rosenfeld-tropical:  96%|█████████████████████████████████▌ | 230/240 [00:18<00:00, 12.60it/s]
# Processing CHN files for rosenfeld-tropical:  97%|█████████████████████████████████▊ | 232/240 [00:18<00:00, 12.60it/s]
# Processing CHN files for rosenfeld-tropical:  98%|██████████████████████████████████▏| 234/240 [00:18<00:00, 12.66it/s]
# Processing CHN files for rosenfeld-tropical:  98%|██████████████████████████████████▍| 236/240 [00:18<00:00, 12.65it/s]
# Processing CHN files for rosenfeld-tropical:  99%|██████████████████████████████████▋| 238/240 [00:18<00:00, 12.65it/s]
# Processing CHN files for rosenfeld-tropical: 100%|███████████████████████████████████| 240/240 [00:19<00:00, 12.60it/s]
#
# Processing CHN files for summer-deep-convective:   0%|                                         | 0/240 [00:00<?, ?it/s]
# Processing CHN files for summer-deep-convective:   1%|▎                                | 2/240 [00:00<00:18, 12.77it/s]
# Processing CHN files for summer-deep-convective:   2%|▌                                | 4/240 [00:00<00:18, 12.82it/s]
# Processing CHN files for summer-deep-convective:   2%|▊                                | 6/240 [00:00<00:18, 12.87it/s]
# Processing CHN files for summer-deep-convective:   3%|█                                | 8/240 [00:00<00:18, 12.62it/s]
# Processing CHN files for summer-deep-convective:   4%|█▎                              | 10/240 [00:00<00:18, 12.67it/s]
# Processing CHN files for summer-deep-convective:   5%|█▌                              | 12/240 [00:00<00:17, 12.73it/s]
# Processing CHN files for summer-deep-convective:   6%|█▊                              | 14/240 [00:01<00:17, 12.71it/s]
# Processing CHN files for summer-deep-convective:   7%|██▏                             | 16/240 [00:01<00:17, 12.75it/s]
# Processing CHN files for summer-deep-convective:   8%|██▍                             | 18/240 [00:01<00:17, 12.84it/s]
# Processing CHN files for summer-deep-convective:   8%|██▋                             | 20/240 [00:01<00:17, 12.87it/s]
# Processing CHN files for summer-deep-convective:   9%|██▉                             | 22/240 [00:01<00:16, 12.97it/s]
# Processing CMP files for marshall-palmer:   4%|█▌                                      | 9/240 [00:00<00:09, 23.75it/s]
# Processing CMP files for marshall-palmer:   5%|█▉                                     | 12/240 [00:00<00:09, 23.76it/s]
# Processing CMP files for marshall-palmer:   6%|██▍                                    | 15/240 [00:00<00:09, 23.74it/s]
# Processing CMP files for marshall-palmer:   8%|██▉                                    | 18/240 [00:00<00:09, 23.66it/s]
# Processing CMP files for marshall-palmer:   9%|███▍                                   | 21/240 [00:00<00:09, 23.51it/s]
# Processing CMP files for marshall-palmer:  10%|███▉                                   | 24/240 [00:01<00:09, 23.46it/s]
# Processing CMP files for marshall-palmer:  11%|████▍                                  | 27/240 [00:01<00:09, 23.38it/s]
# Processing CMP files for marshall-palmer:  12%|████▉                                  | 30/240 [00:01<00:08, 23.64it/s]
# Processing CMP files for marshall-palmer:  14%|█████▎                                 | 33/240 [00:01<00:08, 23.74it/s]
# Processing CMP files for marshall-palmer:  15%|█████▊                                 | 36/240 [00:01<00:08, 23.92it/s]
# Processing CMP files for marshall-palmer:  16%|██████▎                                | 39/240 [00:01<00:08, 23.90it/s]
# Processing CMP files for marshall-palmer:  18%|██████▊                                | 42/240 [00:01<00:08, 23.90it/s]
# Processing CMP files for marshall-palmer:  19%|███████▎                               | 45/240 [00:01<00:08, 23.79it/s]
# Processing CMP files for marshall-palmer:  20%|███████▊                               | 48/240 [00:02<00:08, 23.89it/s]
# Processing CMP files for marshall-palmer:  21%|████████▎                              | 51/240 [00:02<00:07, 23.89it/s]
# Processing CMP files for marshall-palmer:  22%|████████▊                              | 54/240 [00:02<00:07, 23.98it/s]
# Processing CMP files for marshall-palmer:  24%|█████████▎                             | 57/240 [00:02<00:07, 23.77it/s]
# Processing CMP files for marshall-palmer:  25%|█████████▊                             | 60/240 [00:02<00:07, 22.65it/s]
# Processing CMP files for marshall-palmer:  26%|██████████▏                            | 63/240 [00:02<00:07, 23.00it/s]
# Processing CMP files for marshall-palmer:  28%|██████████▋                            | 66/240 [00:02<00:07, 23.44it/s]
# Processing CMP files for marshall-palmer:  29%|███████████▏                           | 69/240 [00:02<00:07, 23.44it/s]
# Processing CMP files for marshall-palmer:  30%|███████████▋                           | 72/240 [00:03<00:07, 23.54it/s]
# Processing CMP files for marshall-palmer:  31%|████████████▏                          | 75/240 [00:03<00:06, 23.60it/s]
# Processing CMP files for marshall-palmer:  32%|████████████▋                          | 78/240 [00:03<00:06, 23.74it/s]
# Processing CMP files for marshall-palmer:  34%|█████████████▏                         | 81/240 [00:03<00:06, 23.68it/s]
# Processing CMP files for marshall-palmer:  35%|█████████████▋                         | 84/240 [00:03<00:06, 23.54it/s]
# Processing CMP files for marshall-palmer:  36%|██████████████▏                        | 87/240 [00:03<00:06, 23.56it/s]
# Processing CMP files for marshall-palmer:  38%|██████████████▋                        | 90/240 [00:03<00:06, 23.71it/s]
# Processing CMP files for marshall-palmer:  39%|███████████████                        | 93/240 [00:03<00:06, 23.72it/s]
# ...
# 239   SVP      rosenfeld-tropical        0.1    58.404906   7.642310    0.534379   4.728626    0.534379   16.148730     0.752787  0.860965        37.0
# 240   SVP      rosenfeld-tropical        0.5    78.351625   8.851645    0.523307   4.984614    0.523307  -17.545446     0.796731  1.212789        26.0
# 241   SVP      rosenfeld-tropical        1.0   112.307962  10.597545    0.486538   6.037971    0.486538  -36.776417     0.828724  1.581688        18.0
# 242   SVP      rosenfeld-tropical        2.0   218.772039  14.790945    0.457591   9.316582    0.457591  -37.666980     0.903970  1.604286         7.0
# 243   SVP      rosenfeld-tropical        5.0   499.370015  22.346588   -1.660611  17.451906   -1.660611  -73.636735    -1.000000  3.793157         2.0
# 244   SVP      rosenfeld-tropical       10.0          NaN        NaN         NaN        NaN         NaN         NaN          NaN       NaN         0.0
# 245   SVP  summer-deep-convective        0.0    70.268292   8.382618    0.439801   4.345926    0.439801  -13.938025     0.756935  1.161953        37.0
# 246   SVP  summer-deep-convective        0.1    70.268292   8.382618    0.439801   4.345926    0.439801  -13.938025     0.756935  1.161953        37.0
# 247   SVP  summer-deep-convective        0.5   114.650254  10.707486    0.342696   5.305165    0.342696  -40.901858     0.810809  1.692101        24.0
# 248   SVP  summer-deep-convective        1.0   175.786841  13.258463    0.262807   7.124570    0.262807  -55.614906     0.845807  2.253009        16.0
# 249   SVP  summer-deep-convective        2.0   323.321611  17.981146    0.190665  10.568275    0.190665  -57.608717     0.923798  2.358976         7.0
# 250   SVP  summer-deep-convective        5.0          NaN        NaN         NaN        NaN         NaN         NaN          NaN       NaN         0.0
# 251   SVP  summer-deep-convective       10.0          NaN        NaN         NaN        NaN         NaN         NaN          NaN       NaN         0.0
#
# Detailed results and summary saved in ./0Zprocessing_data/0analysis_results/

# %% [markdown]
# ## เขียนค่าสถิติตาม threshold เพื่อนำไปใช้ต่อในการโมเสคด้วยการใช้ MFB เป็นตัวคูณปรับแก้ก่อนโมเสค

# %%
def process_summary_results(input_file, output_dir):
    # Read the summary results
    df = pd.read_csv(input_file)
    
    # เลือกสร้างไฟล์ที่มีค่าฝนมากกว่า 0 และ 1.0 ในระดับรายชั่วโมง
    thresholds = [0, 1.0]
    
    for threshold in thresholds:
        # Filter the dataframe for the current threshold
        df_threshold = df[df['Threshold'] == threshold]
        
        # Prepare the output dataframe, now including the Threshold column
        output_df = df_threshold[['Radar', 'ZR_Relation', 'Threshold', 'MSE', 'RMSE', 'R-squared', 'MAE', 'NSE', 'PBIAS', 'Correlation', 'MFB']]
        
        # Sort the dataframe by Radar and ZR_Relation
        output_df = output_df.sort_values(['Radar', 'ZR_Relation'])
        
        # Define the output file path
        output_file = os.path.join(output_dir, f'combined_results_threshold_{threshold}.csv')
        
        # Save the dataframe to CSV
        output_df.to_csv(output_file, index=False)
        
        print(f"File saved: {output_file}")

# Usage
input_file = './0Zprocessing_data/0analysis_results/summary_results.csv'
output_dir = './0Zprocessing_data/0analysis_results/'

process_summary_results(input_file, output_dir)
